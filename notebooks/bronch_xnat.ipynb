# %% [markdown]
# # Bronchoscopy dataset

# %%
import pandas as pd
import os
from datetime import datetime

# %%
cli = "/home/local/VANDERBILT/litz/data/bronch/bronch_raw.xlsm"
dates = "/home/local/VANDERBILT/litz/data/bronch/bronch_dates.xlsx"
cli = pd.read_excel(cli, dtype={'MRN':str}) 
dates = pd.read_excel(dates, dtype={'MRN':str, 'MCL ID':str})
print(f"subjects in clinical data: {len(cli['MRN'].unique())}")
print(f"subjects in dates data: {len(dates['MRN'].unique())}")

# subjects may have multiple nodules - group by largest nodule
largest_nodule = cli.iloc[cli.groupby('MRN')['Size of Nodule (Specific) (cm)'].idxmax()]

sessions = largest_nodule.merge(dates, on='MRN')
sessions
# Out:
# subjects in clinical data: 387
# subjects in dates data: 391
#      Record ID_x       MRN Final nodule diagnosis  Age     Sex  \
# 0            407  10053866                 Benign   62  female
# 1            209  10133197              Malignant   61    male
# 2            209  10133197              Malignant   61    male
# 3            209  10133197              Malignant   61    male
# 4            376  10227932                 Benign   57  female
# ..           ...       ...                    ...  ...     ...
# 443          285   9317355                 Benign   79    male
# 444          107   9608969              Malignant   59    male
# 445          287   9683517                 Benign   56    male
# 446           69   9822032                 Benign   75  female
# 447          300   9876590              Malignant   69  female
#
#      Size of Nodule (Specific) (cm) Smoking Status  \
# 0                               0.8        Current
# 1                               2.5         Former
# 2                               2.5         Former
# 3                               2.5         Former
# 4                               2.4         Former
# ..                              ...            ...
# 443                             2.1         Former
# 444                             1.5         Former
# 445                             3.6         Former
# 446                             1.9         Former
# 447                             1.1         Former
#
#     Does the patient have a history of extrathoracic cancer?  \
# 0                                                   No
# 1                                                   No
# 2                                                   No
# 3                                                   No
# 4                                                   No
# ..                                                 ...
# 443                                                 No
# 444                                                 No
# 445                                                 No
# 446                                                 No
# 447                                                 No
#
#     History of cancer within the past five years? Location of nodule/mass  \
# 0                                              No                     RUL
# 1                                              No                     LUL
# 2                                              No                     LUL
# 3                                              No                     LUL
# 4                                              No                     LLL
# ..                                            ...                     ...
# 443                                            No                     LLL
# 444                                            No                     LUL
# 445                                            No                     LLL
# 446                                            No                     RML
# 447                                            No                     LUL
#
#      ...  \
# 0    ...
# 1    ...
# 2    ...
# 3    ...
# 4    ...
# ..   ...
# 443  ...
# 444  ...
# 445  ...
# 446  ...
# 447  ...
#
#     How was the nodule detected? Ensure you check the original reference scan in PACS  \
# 0                                      screen-detected
# 1                  detected during active surveillance
# 2                  detected during active surveillance
# 3                  detected during active surveillance
# 4                                incidentally detected
# ..                                                 ...
# 443                              incidentally detected
# 444                              incidentally detected
# 445                              incidentally detected
# 446                              incidentally detected
# 447                                    screen-detected
#
#              Primary purpose of reference bronchoscopy Record ID_y  \
# 0                                           diagnostic         407
# 1    tissue sampling for molecular analysis (alread...         209
# 2    tissue sampling for molecular analysis (alread...      220001
# 3    tissue sampling for molecular analysis (alread...      220002
# 4                                           diagnostic         376
# ..                                                 ...         ...
# 443                                         diagnostic         285
# 444                                         diagnostic         107
# 445                                         diagnostic         287
# 446                                         diagnostic          69
# 447                                         diagnostic         300
#
#           MCL ID    Date of Procedure Size of Nodule (cm) HM size Location  \
# 0    27054566930  2018-10-12 00:00:00                 0.8     8.5      RUL
# 1    20802811825  2018-07-27 00:00:00                 2.5     2.6      LUL
# 2    20802811825  2018-06-29 00:00:00                 2.3     2.5      LUL
# 3    20802811825  2018-06-29 00:00:00                 1.2     1.2      RUL
# 4    24540308812  2018-11-01 00:00:00                 2.4     2.6      LLL
# ..           ...                  ...                 ...     ...      ...
# 443  34087001117  2019-03-15 00:00:00                 2.1     2.3      LLL
# 444   5434231673  2018-05-16 00:00:00                 1.5     1.4      LUL
# 445    450204236  2019-03-13 00:00:00                 3.6     3.9      LLL
# 446  41666093991  2018-03-01 00:00:00                 1.9     1.9      RML
# 447   1585785419  2019-03-29 00:00:00                 1.1     1.1      LUL
#
#     Density_y Ref CT date
# 0       Solid  2018-10-04
# 1       Solid  2018-06-12
# 2       Solid  2019-06-10
# 3       Solid  2019-06-10
# 4       Solid  2018-10-25
# ..        ...         ...
# 443     Solid  2019-02-20
# 444     Solid  2018-04-17
# 445     Solid  2019-03-01
# 446     Solid  2018-02-21
# 447     Solid  2019-01-21
#
# [448 rows x 46 columns]

# %%
xnat_path = '/home/local/VANDERBILT/litz/data/ajrccm/xnat20221201/MCL_CT.csv'
xnat = pd.read_csv(xnat_path)
def impute_date(x):
    if pd.isnull(x['Date']):
        try:
            return pd.to_datetime(x['XNAT_CTSESSIONDATA ID'].split('_')[1], format='%Y-%m-%d')
        except:
            return None
    else:
        return pd.to_datetime(x['Date'], format='%Y-%m-%d')
xnat['Date'] = xnat.apply(lambda x: impute_date(x), axis=1)
xnat['Date'] = pd.to_datetime(xnat['Date'], format='%Y-%m-%d')
sessions['Ref CT date'] = pd.to_datetime(sessions['Ref CT date'], format='%Y-%m-%d')

# %%
bronch_xnat = xnat.merge(sessions, left_on=['Subject', 'Date'], right_on=['MCL ID', 'Ref CT date'])
print(f"num sessions: {len(bronch_xnat)}")
print(f"num subjects: {len(bronch_xnat['MCL ID'].unique())}")
sess_str =','.join(bronch_xnat['XNAT_CTSESSIONDATA ID'].tolist())
download = "/home/local/VANDERBILT/litz/data/bronch/bronch_xnat_sessions.txt"
with open(download, 'w') as f:
    f.write(sess_str)
# Out:
# num sessions: 475
# num subjects: 379

# %% [markdown]
# ### Cases and controls
# 1. match scan with nodule record via Record ID
# 2. group by subject

# %%
print(len(dates))
print(len(dates['MCL ID'].unique()))
print(len(cli))
# Out:
# 454
# 391
# 450

# %%
cli_dates = cli.merge(dates, on=['MRN','Record ID'])

# cross sectional cohort
cli_dates['lung_cancer'] = cli_dates['Final nodule diagnosis'].apply(lambda x: int(x=='Malignant'))
cs = cli_dates.iloc[cli_dates.groupby(['MRN'])['lung_cancer'].idxmax()]
cs
# Out:
#      Record ID       MRN Final nodule diagnosis  Age     Sex  \
# 339        407  10053866                 Benign   62  female
# 167        209  10133197              Malignant   61    male
# 311        376  10227932                 Benign   57  female
# 298        363  10244135              Malignant   71  female
# 304        369  10567634                 Benign   74  female
# ..         ...       ...                    ...  ...     ...
# 228        285   9317355                 Benign   79    male
# 82         107   9608969              Malignant   59    male
# 230        287   9683517                 Benign   56    male
# 50          69   9822032                 Benign   75  female
# 241        300   9876590              Malignant   69  female
#
#      Size of Nodule (Specific) (cm) Smoking Status  \
# 339                             0.8        Current
# 167                             2.5         Former
# 311                             2.4         Former
# 298                             3.2         Former
# 304                             3.4          Never
# ..                              ...            ...
# 228                             2.1         Former
# 82                              1.5         Former
# 230                             3.6         Former
# 50                              1.9         Former
# 241                             1.1         Former
#
#     Does the patient have a history of extrathoracic cancer?  \
# 339                                                 No
# 167                                                 No
# 311                                                 No
# 298                                                 No
# 304                                                Yes
# ..                                                 ...
# 228                                                 No
# 82                                                  No
# 230                                                 No
# 50                                                  No
# 241                                                 No
#
#     History of cancer within the past five years? Location of nodule/mass  \
# 339                                            No                     RUL
# 167                                            No                     LUL
# 311                                            No                     LLL
# 298                                            No                     LLL
# 304                                           Yes                     RUL
# ..                                            ...                     ...
# 228                                            No                     LLL
# 82                                             No                     LUL
# 230                                            No                     LLL
# 50                                             No                     RML
# 241                                            No                     LUL
#
#      ...  \
# 339  ...
# 167  ...
# 311  ...
# 298  ...
# 304  ...
# ..   ...
# 228  ...
# 82   ...
# 230  ...
# 50   ...
# 241  ...
#
#     How was the nodule detected? Ensure you check the original reference scan in PACS  \
# 339                                    screen-detected
# 167                detected during active surveillance
# 311                              incidentally detected
# 298                              incidentally detected
# 304                              incidentally detected
# ..                                                 ...
# 228                              incidentally detected
# 82                               incidentally detected
# 230                              incidentally detected
# 50                               incidentally detected
# 241                                    screen-detected
#
#              Primary purpose of reference bronchoscopy       MCL ID  \
# 339                                         diagnostic  27054566930
# 167  tissue sampling for molecular analysis (alread...  20802811825
# 311                                         diagnostic  24540308812
# 298                                         diagnostic  29479908093
# 304                                         diagnostic  14583998995
# ..                                                 ...          ...
# 228                                         diagnostic  34087001117
# 82                                          diagnostic   5434231673
# 230                                         diagnostic    450204236
# 50                                          diagnostic  41666093991
# 241                                         diagnostic   1585785419
#
#        Date of Procedure Size of Nodule (cm) HM size Location Density_y  \
# 339  2018-10-12 00:00:00                 0.8     8.5      RUL     Solid
# 167  2018-07-27 00:00:00                 2.5     2.6      LUL     Solid
# 311  2018-11-01 00:00:00                 2.4     2.6      LLL     Solid
# 298  2018-12-06 00:00:00                 3.2     3.0      LLL     Solid
# 304  2018-12-28 00:00:00                 3.4     3.4      RUL     Solid
# ..                   ...                 ...     ...      ...       ...
# 228  2019-03-15 00:00:00                 2.1     2.3      LLL     Solid
# 82   2018-05-16 00:00:00                 1.5     1.4      LUL     Solid
# 230  2019-03-13 00:00:00                 3.6     3.9      LLL     Solid
# 50   2018-03-01 00:00:00                 1.9     1.9      RML     Solid
# 241  2019-03-29 00:00:00                 1.1     1.1      LUL     Solid
#
#     Ref CT date lung_cancer
# 339  2018-10-04           0
# 167  2018-06-12           1
# 311  2018-10-25           0
# 298  2018-12-03           1
# 304  2018-12-07           0
# ..          ...         ...
# 228  2019-02-20           0
# 82   2018-04-17           1
# 230  2019-03-01           0
# 50   2018-02-21           0
# 241  2019-01-21           1
#
# [385 rows x 46 columns]

# %% [markdown]
# ### Radiologic features

# %%
def get_spiculation(x):
    map = {'Checked':1, 'Unchecked':0}
    return map[x]
def get_upper_lobe(x):
    map = {
        'RUL':1,
        'RML':0,
        'RLL':0,
        'LUL':1,
        'Lingula':0,
        'LLL':0
    }
    return map[x]
def get_nodule_type(x):
    map = {
        'Pure GGO': 0,
        'Part-solid': 1,
        'Solid': 2
    }

cs['spiculation'] = cs['Nodule edge characteristics (choice=Spiculation)'].apply(lambda x: get_spiculation(x))
cs['upper_lobe'] = cs['Location'].apply(lambda x: get_upper_lobe(x))
cs['nodule_size'] = cs['Size of Nodule (Specific) (cm)'].astype(float)
cs['nodule_type'] = cs['Density_x'].apply(lambda x: get_nodule_type(x))
# Out:
# /tmp/ipykernel_2767425/81437705.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cs['spiculation'] = cs['Nodule edge characteristics (choice=Spiculation)'].apply(lambda x: get_spiculation(x))
# /tmp/ipykernel_2767425/81437705.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cs['upper_lobe'] = cs['Location'].apply(lambda x: get_upper_lobe(x))
# /tmp/ipykernel_2767425/81437705.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cs['nodule_size'] = cs['Size of Nodule (Specific) (cm)'].astype(float)
# /tmp/ipykernel_2767425/81437705.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cs['nodule_type'] = cs['Density_x'].apply(lambda x: get_nodule_type(x))

# %% [markdown]
# ### Clinical features

# %%
def get_sex(x):
    map = {
        'male':1,
        'female':0
    }
    return map[x]
def parse_yesno(x):
    map = {
        'Yes':True,
        'No':False
    }
    return map[x]

def get_smo_status(x):
    map = {
        'Former': 0,
        'Current':1,
        'Never':2
    }
    return map[x]

cs['age'] = cs['Age']
cs['sex'] = cs['Sex'].apply(lambda x: get_sex(x))
cs['bmi'] = cs['BMI:'].astype(float)
cs['phist_extrathoracic'] = cs['Does the patient have a history of extrathoracic cancer?'].apply(lambda x: parse_yesno(x))
cs['phist_primary'] = cs['Does the patient have a history of prior primary lung cancer?'].apply(lambda x: parse_yesno(x))
cs['phist'] = (cs['phist_extrathoracic'] | cs['phist_primary']).astype(int)
cs['fhist'] = cs['Family history of lung cancer?'].apply(lambda x: parse_yesno(x)).astype(int)
cs['emphysema'] = cs['Radiographic emphysema present?'].apply(lambda x: parse_yesno(x)).astype(int)
cs['copd'] = cs['History of COPD?'].apply(lambda x: parse_yesno(x)).astype(int)
cs['smo_status'] = cs['Smoking Status'].apply(lambda x: get_smo_status(x))
cs['pkyr'] = cs['Pack year history of smoking:']
cs['quit_time'] = cs['Years since quitting smoking: Enter 0 if still active smoker at time of bronchoscopy']
# Out:
# /tmp/ipykernel_2767425/2045154213.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cs['age'] = cs['Age']
# /tmp/ipykernel_2767425/2045154213.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cs['sex'] = cs['Sex'].apply(lambda x: get_sex(x))
# /tmp/ipykernel_2767425/2045154213.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cs['bmi'] = cs['BMI:'].astype(float)
# /tmp/ipykernel_2767425/2045154213.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cs['phist_extrathoracic'] = cs['Does the patient have a history of extrathoracic cancer?'].apply(lambda x: parse_yesno(x))
# /tmp/ipykernel_2767425/2045154213.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cs['phist_primary'] = cs['Does the patient have a history of prior primary lung cancer?'].apply(lambda x: parse_yesno(x))
# /tmp/ipykernel_2767425/2045154213.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cs['phist'] = (cs['phist_extrathoracic'] | cs['phist_primary']).astype(int)
# /tmp/ipykernel_2767425/2045154213.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cs['fhist'] = cs['Family history of lung cancer?'].apply(lambda x: parse_yesno(x)).astype(int)
# /tmp/ipykernel_2767425/2045154213.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cs['emphysema'] = cs['Radiographic emphysema present?'].apply(lambda x: parse_yesno(x)).astype(int)
# /tmp/ipykernel_2767425/2045154213.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cs['copd'] = cs['History of COPD?'].apply(lambda x: parse_yesno(x)).astype(int)
# /tmp/ipykernel_2767425/2045154213.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cs['smo_status'] = cs['Smoking Status'].apply(lambda x: get_smo_status(x))
# /tmp/ipykernel_2767425/2045154213.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cs['pkyr'] = cs['Pack year history of smoking:']
# /tmp/ipykernel_2767425/2045154213.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cs['quit_time'] = cs['Years since quitting smoking: Enter 0 if still active smoker at time of bronchoscopy']

# %%
clinical_ft = ['pid', 'age', 'sex', 'bmi', 'emphysema', 'copd', 'phist', 'fhist', 'smo_status', 'quit_time', 'pkyr', 'lung_cancer']
cs['pid'] = cs['MCL ID']
cs = cs[clinical_ft]
cs
# Out:
# /tmp/ipykernel_2767425/3268624060.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cs['pid'] = cs['MCL ID']
#              pid  age  sex   bmi  emphysema  copd  phist  fhist  smo_status  \
# 339  27054566930   62    0  21.6          1     1      0      0           1
# 167  20802811825   61    1  20.9          1     1      1      0           0
# 311  24540308812   57    0  22.1          1     1      0      0           0
# 298  29479908093   71    0  22.7          1     1      0      1           0
# 304  14583998995   74    0  25.3          0     0      1      0           2
# ..           ...  ...  ...   ...        ...   ...    ...    ...         ...
# 228  34087001117   79    1  25.8          0     0      0      1           0
# 82    5434231673   59    1  24.4          0     1      0      0           0
# 230    450204236   56    1  38.3          0     0      0      0           0
# 50   41666093991   75    0  18.0          0     0      0      0           0
# 241   1585785419   69    0  34.2          1     1      0      0           0
#
#      quit_time  pkyr  lung_cancer
# 339        0.0  40.0            0
# 167        3.0  66.0            1
# 311        0.0  60.0            0
# 298       10.0  40.0            1
# 304        NaN   0.0            0
# ..         ...   ...          ...
# 228       40.0  20.0            0
# 82         0.0  15.0            1
# 230       38.0   NaN            0
# 50        35.0   NaN            0
# 241        0.0  92.0            1
#
# [385 rows x 12 columns]

# %% [markdown]
# ### Get nifti scans

# %%
scan_dir = "/nfs/masi/MCL/xnat/xnat20221207_bronch/bronch"
rows = []
for mcl in os.listdir(scan_dir):
    for scanid in os.listdir(os.path.join(scan_dir, mcl)):
        try:
            scan_date = datetime.strptime(scanid, "%Y%m%d")
            for fname in os.listdir(os.path.join(scan_dir, mcl, scanid)):
                rows.append({'pid': mcl, 'scan_date': scan_date, 'filename':fname})
        except:
            continue

# prep_dir = "/home/local/VANDERBILT/litz/data/bronch/DeepLungScreening/prep/"
# rows = []
# for p in glob.glob(os.path.join(prep_dir, "*_clean.nii.gz")):
#     scanid = os.path.basename(p).split('_clean.nii.gz')[0]
#     mcl, date = scanid.split('time')
#     scan_date = datetime.strptime(date, "%Y%m%d")
#     rows.append({'pid': mcl, 'scan_date': scan_date, 'filename': scanid})


scan_df = pd.DataFrame(rows)
scan_df = scan_df.sort_values(by=['pid', 'scan_date'])
scan_df['session'] = scan_df.groupby(['pid'])['scan_date'].rank('dense', ascending=True) # assign a T0, T1, or T2 for each scan
scan_df['session'] = scan_df['session'] - 1
scan_df['session'] = scan_df['session'].astype(int)
scan_df
# Out:
#              pid  scan_date                        filename  session
# 345  10140118338 2018-10-19  10140118338time20181019.nii.gz        0
# 231  10232218755 2019-02-04  10232218755time20190204.nii.gz        0
# 144  10302863632 2019-02-16  10302863632time20190216.nii.gz        0
# 7    10310069205 2018-10-05  10310069205time20181005.nii.gz        0
# 368  10501496583 2019-01-08  10501496583time20190108.nii.gz        0
# ..           ...        ...                             ...      ...
# 29    8666755991 2017-12-01   8666755991time20171201.nii.gz        0
# 15    9057763661 2018-08-10   9057763661time20180810.nii.gz        0
# 227   9345567287 2018-07-13   9345567287time20180713.nii.gz        0
# 232   9473800086 2018-08-13   9473800086time20180813.nii.gz        0
# 89    9540380572 2017-11-06   9540380572time20171106.nii.gz        0
#
# [391 rows x 4 columns]

# %%
cohort = cs.merge(scan_df, on='pid')
cohort['id'] = cohort['filename'].apply(lambda x: x.split('.nii.gz')[0])
cohort
cohort_path = "/home/local/VANDERBILT/litz/github/MASILab/DeepLungScreening/cohorts/bronch/bronch_v1.csv"
cohort.to_csv(cohort_path, index=False)

# %%
cohort
# Out:
#              pid  age  sex   bmi  emphysema  copd  phist  fhist  smo_status  \
# 0    27054566930   62    0  21.6          1     1      0      0           1
# 1    20802811825   61    1  20.9          1     1      1      0           0
# 2    20802811825   61    1  20.9          1     1      1      0           0
# 3    24540308812   57    0  22.1          1     1      0      0           0
# 4    29479908093   71    0  22.7          1     1      0      1           0
# ..           ...  ...  ...   ...        ...   ...    ...    ...         ...
# 386  34087001117   79    1  25.8          0     0      0      1           0
# 387   5434231673   59    1  24.4          0     1      0      0           0
# 388    450204236   56    1  38.3          0     0      0      0           0
# 389  41666093991   75    0  18.0          0     0      0      0           0
# 390   1585785419   69    0  34.2          1     1      0      0           0
#
#      quit_time  pkyr  lung_cancer  scan_date                        filename  \
# 0          0.0  40.0            0 2018-10-04  27054566930time20181004.nii.gz
# 1          3.0  66.0            1 2018-06-12  20802811825time20180612.nii.gz
# 2          3.0  66.0            1 2019-06-10  20802811825time20190610.nii.gz
# 3          0.0  60.0            0 2018-10-25  24540308812time20181025.nii.gz
# 4         10.0  40.0            1 2018-12-03  29479908093time20181203.nii.gz
# ..         ...   ...          ...        ...                             ...
# 386       40.0  20.0            0 2019-02-20  34087001117time20190220.nii.gz
# 387        0.0  15.0            1 2018-04-17   5434231673time20180417.nii.gz
# 388       38.0   NaN            0 2019-03-01    450204236time20190301.nii.gz
# 389       35.0   NaN            0 2018-02-21  41666093991time20180221.nii.gz
# 390        0.0  92.0            1 2019-01-21   1585785419time20190121.nii.gz
#
#      session                       id
# 0          0  27054566930time20181004
# 1          0  20802811825time20180612
# 2          1  20802811825time20190610
# 3          0  24540308812time20181025
# 4          0  29479908093time20181203
# ..       ...                      ...
# 386        0  34087001117time20190220
# 387        0   5434231673time20180417
# 388        0    450204236time20190301
# 389        0  41666093991time20180221
# 390        0   1585785419time20190121
#
# [391 rows x 16 columns]

# %%
ft =['pid', 'id','session', 'age', 'sex', 'bmi', 'emphysema', 'copd', 'phist', 'fhist', 'smo_status', 'quit_time', 'pkyr', 'lung_cancer', 'with_image', 'with_marker']

# %% [markdown]
# ### available features
# * demo - age, sex, BMI
# * risk factors - fhist, phist of any cancer or past 5 years, COPD, emphysema, pkyr, smoking quit time, smoking status, nodule spiculation, nodule location
# * nodule pathology
#
# missing: race, education

# %%
bronch['Final nodule diagnosis'].value_counts(dropna=False)
# Out:
# Malignant    273
# Benign       177
# Name: Final nodule diagnosis, dtype: int64

# %%
# group nodules
bronch['lung_cancer'] = bronch['Final nodule diagnosis'].apply(lambda x: int(x=='Malignant'))
idxmax = bronch.groupby(['MRN'])['lung_cancer'].idxmax()
cohort = bronch.loc[idxmax]
cohort
# Out:
#      Record ID       MRN Final nodule diagnosis  Age     Sex  \
# 343        407  10053866                 Benign   62  female
# 170        209  10133197              Malignant   61    male
# 315        376  10227932                 Benign   57  female
# 302        363  10244135              Malignant   71  female
# 308        369  10567634                 Benign   74  female
# ..         ...       ...                    ...  ...     ...
# 232        285   9317355                 Benign   79    male
# 84         107   9608969              Malignant   59    male
# 234        287   9683517                 Benign   56    male
# 52          69   9822032                 Benign   75  female
# 245        300   9876590              Malignant   69  female
#
#      Size of Nodule (Specific) (cm) Smoking Status  \
# 343                             0.8        Current
# 170                             2.5         Former
# 315                             2.4         Former
# 302                             3.2         Former
# 308                             3.4          Never
# ..                              ...            ...
# 232                             2.1         Former
# 84                              1.5         Former
# 234                             3.6         Former
# 52                              1.9         Former
# 245                             1.1         Former
#
#     Does the patient have a history of extrathoracic cancer?  \
# 343                                                 No
# 170                                                 No
# 315                                                 No
# 302                                                 No
# 308                                                Yes
# ..                                                 ...
# 232                                                 No
# 84                                                  No
# 234                                                 No
# 52                                                  No
# 245                                                 No
#
#     History of cancer within the past five years? Location of nodule/mass  \
# 343                                            No                     RUL
# 170                                            No                     LUL
# 315                                            No                     LLL
# 302                                            No                     LLL
# 308                                           Yes                     RUL
# ..                                            ...                     ...
# 232                                            No                     LLL
# 84                                             No                     LUL
# 234                                            No                     LLL
# 52                                             No                     RML
# 245                                            No                     LUL
#
#      ... Pack year history of smoking: History of COPD?  \
# 343  ...                          40.0              Yes
# 170  ...                          66.0              Yes
# 315  ...                          60.0              Yes
# 302  ...                          40.0              Yes
# 308  ...                           0.0               No
# ..   ...                           ...              ...
# 232  ...                          20.0               No
# 84   ...                          15.0              Yes
# 234  ...                           NaN               No
# 52   ...                           NaN               No
# 245  ...                          92.0              Yes
#
#     Peripheral 1/3 of lung  \
# 343                    Yes
# 170                    Yes
# 315                    Yes
# 302                    Yes
# 308                    Yes
# ..                     ...
# 232                    Yes
# 84                     Yes
# 234                    Yes
# 52                     Yes
# 245                     No
#
#     Growth of primary nodule noted on surveillance imaging? Choose No if no prior imaging  \
# 343                                                 No
# 170                                                Yes
# 315                                                 No
# 302                                                 No
# 308                                                Yes
# ..                                                 ...
# 232                                                Yes
# 84                                                 Yes
# 234                                                Yes
# 52                                                 Yes
# 245                                                 No
#
#     Presence of pre-procedure symptoms? Includes: unexplained weight loss >5kg, dyspnea, pneumothorax, fatigue, pain or hemoptypsis  \
# 343                                                 No
# 170                                                 No
# 315                                                 No
# 302                                                Yes
# 308                                                 No
# ..                                                 ...
# 232                                                 No
# 84                                                  No
# 234                                                 No
# 52                                                  No
# 245                                                 No
#
#     Pre-bronch percent predicted FEV1 (%): Enter as an integer 1-110  \
# 343                                                NaN
# 170                                               20.0
# 315                                                NaN
# 302                                               56.0
# 308                                                NaN
# ..                                                 ...
# 232                                                NaN
# 84                                                68.0
# 234                                               75.0
# 52                                                 NaN
# 245                                               59.0
#
#     Years since quitting smoking: Enter 0 if still active smoker at time of bronchoscopy  \
# 343                                                0.0
# 170                                                3.0
# 315                                                0.0
# 302                                               10.0
# 308                                                NaN
# ..                                                 ...
# 232                                               40.0
# 84                                                 0.0
# 234                                               38.0
# 52                                                35.0
# 245                                                0.0
#
#     How was the nodule detected? Ensure you check the original reference scan in PACS  \
# 343                                    screen-detected
# 170                detected during active surveillance
# 315                              incidentally detected
# 302                              incidentally detected
# 308                              incidentally detected
# ..                                                 ...
# 232                              incidentally detected
# 84                               incidentally detected
# 234                              incidentally detected
# 52                               incidentally detected
# 245                                    screen-detected
#
#              Primary purpose of reference bronchoscopy lung_cancer
# 343                                         diagnostic           0
# 170  tissue sampling for molecular analysis (alread...           1
# 315                                         diagnostic           0
# 302                                         diagnostic           1
# 308                                         diagnostic           0
# ..                                                 ...         ...
# 232                                         diagnostic           0
# 84                                          diagnostic           1
# 234                                         diagnostic           0
# 52                                          diagnostic           0
# 245                                         diagnostic           1
#
# [387 rows x 39 columns]

# %%
cohort['lung_cancer'].value_counts()
# Out:
# 1    236
# 0    151
# Name: lung_cancer, dtype: int64

# %%
bronch_path = "/home/local/VANDERBILT/litz/data/bronch/Bronch MCL.csv"
bronch = pd.read_csv(bronch_path, dtype={'MCL ID': str})
bronch = bronch.rename(columns={'MCL ID': 'mcl_id'})
