# %% [markdown]
# # Bronchoscopy dataset

# %% [markdown]
# ### available features
# * demo - age, sex, BMI
# * risk factors - fhist, phist of any cancer or past 5 years, COPD, emphysema, pkyr, smoking quit time, smoking status, nodule spiculation, nodule location
# * nodule pathology
#
# missing: race, education

# %%
import pandas as pd
import os
from datetime import datetime
import glob

# %%
cli = "/home/local/VANDERBILT/litz/data/bronch/bronch_raw.xlsm"
dates = "/home/local/VANDERBILT/litz/data/bronch/bronch_dates.xlsx"
cli = pd.read_excel(cli, dtype={'MRN':str}) 
dates = pd.read_excel(dates, dtype={'MRN':str, 'MCL ID':str})
print(f"subjects in clinical data: {len(cli['MRN'].unique())}")
print(f"subjects in dates data: {len(dates['MRN'].unique())}")

# subjects may have multiple nodules - group by largest nodule
largest_nodule = cli.iloc[cli.groupby('MRN')['Size of Nodule (Specific) (cm)'].idxmax()]

sessions = largest_nodule.merge(dates, on='MRN')
sessions
# Out:
# subjects in clinical data: 387
# subjects in dates data: 391
#      Record ID_x       MRN Final nodule diagnosis  Age     Sex  \
# 0            407  10053866                 Benign   62  female
# 1            209  10133197              Malignant   61    male
# 2            209  10133197              Malignant   61    male
# 3            209  10133197              Malignant   61    male
# 4            376  10227932                 Benign   57  female
# ..           ...       ...                    ...  ...     ...
# 443          285   9317355                 Benign   79    male
# 444          107   9608969              Malignant   59    male
# 445          287   9683517                 Benign   56    male
# 446           69   9822032                 Benign   75  female
# 447          300   9876590              Malignant   69  female
#
#      Size of Nodule (Specific) (cm) Smoking Status  \
# 0                               0.8        Current
# 1                               2.5         Former
# 2                               2.5         Former
# 3                               2.5         Former
# 4                               2.4         Former
# ..                              ...            ...
# 443                             2.1         Former
# 444                             1.5         Former
# 445                             3.6         Former
# 446                             1.9         Former
# 447                             1.1         Former
#
#     Does the patient have a history of extrathoracic cancer?  \
# 0                                                   No
# 1                                                   No
# 2                                                   No
# 3                                                   No
# 4                                                   No
# ..                                                 ...
# 443                                                 No
# 444                                                 No
# 445                                                 No
# 446                                                 No
# 447                                                 No
#
#     History of cancer within the past five years? Location of nodule/mass  \
# 0                                              No                     RUL
# 1                                              No                     LUL
# 2                                              No                     LUL
# 3                                              No                     LUL
# 4                                              No                     LLL
# ..                                            ...                     ...
# 443                                            No                     LLL
# 444                                            No                     LUL
# 445                                            No                     LLL
# 446                                            No                     RML
# 447                                            No                     LUL
#
#      ...  \
# 0    ...
# 1    ...
# 2    ...
# 3    ...
# 4    ...
# ..   ...
# 443  ...
# 444  ...
# 445  ...
# 446  ...
# 447  ...
#
#     How was the nodule detected? Ensure you check the original reference scan in PACS  \
# 0                                      screen-detected
# 1                  detected during active surveillance
# 2                  detected during active surveillance
# 3                  detected during active surveillance
# 4                                incidentally detected
# ..                                                 ...
# 443                              incidentally detected
# 444                              incidentally detected
# 445                              incidentally detected
# 446                              incidentally detected
# 447                                    screen-detected
#
#              Primary purpose of reference bronchoscopy Record ID_y  \
# 0                                           diagnostic         407
# 1    tissue sampling for molecular analysis (alread...         209
# 2    tissue sampling for molecular analysis (alread...      220001
# 3    tissue sampling for molecular analysis (alread...      220002
# 4                                           diagnostic         376
# ..                                                 ...         ...
# 443                                         diagnostic         285
# 444                                         diagnostic         107
# 445                                         diagnostic         287
# 446                                         diagnostic          69
# 447                                         diagnostic         300
#
#           MCL ID    Date of Procedure Size of Nodule (cm) HM size Location  \
# 0    27054566930  2018-10-12 00:00:00                 0.8     8.5      RUL
# 1    20802811825  2018-07-27 00:00:00                 2.5     2.6      LUL
# 2    20802811825  2018-06-29 00:00:00                 2.3     2.5      LUL
# 3    20802811825  2018-06-29 00:00:00                 1.2     1.2      RUL
# 4    24540308812  2018-11-01 00:00:00                 2.4     2.6      LLL
# ..           ...                  ...                 ...     ...      ...
# 443  34087001117  2019-03-15 00:00:00                 2.1     2.3      LLL
# 444   5434231673  2018-05-16 00:00:00                 1.5     1.4      LUL
# 445    450204236  2019-03-13 00:00:00                 3.6     3.9      LLL
# 446  41666093991  2018-03-01 00:00:00                 1.9     1.9      RML
# 447   1585785419  2019-03-29 00:00:00                 1.1     1.1      LUL
#
#     Density_y Ref CT date
# 0       Solid  2018-10-04
# 1       Solid  2018-06-12
# 2       Solid  2019-06-10
# 3       Solid  2019-06-10
# 4       Solid  2018-10-25
# ..        ...         ...
# 443     Solid  2019-02-20
# 444     Solid  2018-04-17
# 445     Solid  2019-03-01
# 446     Solid  2018-02-21
# 447     Solid  2019-01-21
#
# [448 rows x 46 columns]

# %%
xnat_path = '/home/local/VANDERBILT/litz/data/ajrccm/xnat20221201/MCL_CT.csv'
xnat = pd.read_csv(xnat_path)
def impute_date(x):
    if pd.isnull(x['Date']):
        try:
            return pd.to_datetime(x['XNAT_CTSESSIONDATA ID'].split('_')[1], format='%Y-%m-%d')
        except:
            return None
    else:
        return pd.to_datetime(x['Date'], format='%Y-%m-%d')
xnat['Date'] = xnat.apply(lambda x: impute_date(x), axis=1)
xnat['Date'] = pd.to_datetime(xnat['Date'], format='%Y-%m-%d')
sessions['Ref CT date'] = pd.to_datetime(sessions['Ref CT date'], format='%Y-%m-%d')
sessions[['MCL ID', 'Date', 'Ref CT date']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 14
#      12 xnat['Date'] = pd.to_datetime(xnat['Date'], format='%Y-%m-%d')
#      13 sessions['Ref CT date'] = pd.to_datetime(sessions['Ref CT date'], format='%Y-%m-%d')
# ---> 14 sessions[['MCL ID', 'Date', 'Ref CT date']]
#
# File /home-nfs2/local/VANDERBILT/litz/github/MASILab/DeepLungScreening/env/lib/python3.8/site-packages/pandas/core/frame.py:3811, in DataFrame.__getitem__(self, key)
#    3809     if is_iterator(key):
#    3810         key = list(key)
# -> 3811     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3813 # take() does not accept boolean indexers
#    3814 if getattr(indexer, "dtype", None) == bool:
#
# File /home-nfs2/local/VANDERBILT/litz/github/MASILab/DeepLungScreening/env/lib/python3.8/site-packages/pandas/core/indexes/base.py:6113, in Index._get_indexer_strict(self, key, axis_name)
#    6110 else:
#    6111     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6113 self._raise_if_missing(keyarr, indexer, axis_name)
#    6115 keyarr = self.take(indexer)
#    6116 if isinstance(key, Index):
#    6117     # GH 42790 - Preserve name from an Index
#
# File /home-nfs2/local/VANDERBILT/litz/github/MASILab/DeepLungScreening/env/lib/python3.8/site-packages/pandas/core/indexes/base.py:6176, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6173     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6175 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6176 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['Date'] not in index"

# %%
# bronch_xnat = xnat.merge(sessions, left_on=['Subject', 'Date'], right_on=['MCL ID', 'Ref CT date'])
# print(f"num sessions: {len(bronch_xnat)}")
# print(f"num subjects: {len(bronch_xnat['MCL ID'].unique())}")
# sess_str =','.join(bronch_xnat['XNAT_CTSESSIONDATA ID'].tolist())
# download = "/home/local/VANDERBILT/litz/data/bronch/bronch_xnat_sessions.txt"
# with open(download, 'w') as f:
#     f.write(sess_str)

# %% [markdown]
# ### Cases and controls
# 1. match scan with nodule record via Record ID
# 2. group by subject

# %%
print(len(dates))
print(len(dates['MCL ID'].unique()))
print(len(cli))
# Out:
# 454
# 391
# 450

# %%
nodule_counts = cli.groupby('MRN', as_index=False)['Sex'].count().rename(columns={'Sex':'nodule_count'})
cli = cli.merge(nodule_counts, on='MRN')
cli_dates = cli.merge(dates, on=['MRN','Record ID'])

# cross sectional cohort
cli_dates['lung_cancer'] = cli_dates['Final nodule diagnosis'].apply(lambda x: int(x=='Malignant'))
cs = cli_dates.iloc[cli_dates.groupby(['MRN'])['lung_cancer'].idxmax()]
cs
# Out:
#      Record ID       MRN Final nodule diagnosis  Age     Sex  \
# 345        407  10053866                 Benign   62  female
# 173        209  10133197              Malignant   61    male
# 318        376  10227932                 Benign   57  female
# 305        363  10244135              Malignant   71  female
# 311        369  10567634                 Benign   74  female
# ..         ...       ...                    ...  ...     ...
# 234        285   9317355                 Benign   79    male
# 87         107   9608969              Malignant   59    male
# 236        287   9683517                 Benign   56    male
# 54          69   9822032                 Benign   75  female
# 247        300   9876590              Malignant   69  female
#
#      Size of Nodule (Specific) (cm) Smoking Status  \
# 345                             0.8        Current
# 173                             2.5         Former
# 318                             2.4         Former
# 305                             3.2         Former
# 311                             3.4          Never
# ..                              ...            ...
# 234                             2.1         Former
# 87                              1.5         Former
# 236                             3.6         Former
# 54                              1.9         Former
# 247                             1.1         Former
#
#     Does the patient have a history of extrathoracic cancer?  \
# 345                                                 No
# 173                                                 No
# 318                                                 No
# 305                                                 No
# 311                                                Yes
# ..                                                 ...
# 234                                                 No
# 87                                                  No
# 236                                                 No
# 54                                                  No
# 247                                                 No
#
#     History of cancer within the past five years? Location of nodule/mass  \
# 345                                            No                     RUL
# 173                                            No                     LUL
# 318                                            No                     LLL
# 305                                            No                     LLL
# 311                                           Yes                     RUL
# ..                                            ...                     ...
# 234                                            No                     LLL
# 87                                             No                     LUL
# 236                                            No                     LLL
# 54                                             No                     RML
# 247                                            No                     LUL
#
#      ... nodule_count_y nodule_count       MCL ID    Date of Procedure  \
# 345  ...              1            1  27054566930  2018-10-12 00:00:00
# 173  ...              3            3  20802811825  2018-07-27 00:00:00
# 318  ...              1            1  24540308812  2018-11-01 00:00:00
# 305  ...              1            1  29479908093  2018-12-06 00:00:00
# 311  ...              1            1  14583998995  2018-12-28 00:00:00
# ..   ...            ...          ...          ...                  ...
# 234  ...              1            1  34087001117  2019-03-15 00:00:00
# 87   ...              1            1   5434231673  2018-05-16 00:00:00
# 236  ...              1            1    450204236  2019-03-13 00:00:00
# 54   ...              1            1  41666093991  2018-03-01 00:00:00
# 247  ...              1            1   1585785419  2019-03-29 00:00:00
#
#     Size of Nodule (cm) HM size Location Density_y Ref CT date lung_cancer
# 345                 0.8     8.5      RUL     Solid  2018-10-04           0
# 173                 2.5     2.6      LUL     Solid  2018-06-12           1
# 318                 2.4     2.6      LLL     Solid  2018-10-25           0
# 305                 3.2     3.0      LLL     Solid  2018-12-03           1
# 311                 3.4     3.4      RUL     Solid  2018-12-07           0
# ..                  ...     ...      ...       ...         ...         ...
# 234                 2.1     2.3      LLL     Solid  2019-02-20           0
# 87                  1.5     1.4      LUL     Solid  2018-04-17           1
# 236                 3.6     3.9      LLL     Solid  2019-03-01           0
# 54                  1.9     1.9      RML     Solid  2018-02-21           0
# 247                 1.1     1.1      LUL     Solid  2019-01-21           1
#
# [385 rows x 49 columns]

# %% [markdown]
# ### Radiologic features

# %%
def get_spiculation(x):
    map = {'Checked':1, 'Unchecked':0}
    return map[x]
def get_upper_lobe(x):
    map = {
        'RUL':1,
        'RML':0,
        'RLL':0,
        'LUL':1,
        'Lingula':0,
        'LLL':0
    }
    return map[x]
def get_nodule_type(x):
    map = {
        'Pure GGO': 0,
        'Part-solid': 1,
        'Solid': 2
    }
    return map[x]

cs['spiculation'] = cs['Nodule edge characteristics (choice=Spiculation)'].apply(lambda x: get_spiculation(x))
cs['upper_lobe'] = cs['Location'].apply(lambda x: get_upper_lobe(x))
cs['nodule_size'] = cs['Size of Nodule (Specific) (cm)'].astype(float)
cs['nodule_type'] = cs['Density_x'].apply(lambda x: get_nodule_type(x))
cs['nodule_count'] = cs['nodule_count']
# Out:
# /tmp/ipykernel_3401216/3501071108.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cs['spiculation'] = cs['Nodule edge characteristics (choice=Spiculation)'].apply(lambda x: get_spiculation(x))
# /tmp/ipykernel_3401216/3501071108.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cs['upper_lobe'] = cs['Location'].apply(lambda x: get_upper_lobe(x))
# /tmp/ipykernel_3401216/3501071108.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cs['nodule_size'] = cs['Size of Nodule (Specific) (cm)'].astype(float)
# /tmp/ipykernel_3401216/3501071108.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cs['nodule_type'] = cs['Density_x'].apply(lambda x: get_nodule_type(x))
# /tmp/ipykernel_3401216/3501071108.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cs['nodule_count'] = cs['nodule_count']

# %% [markdown]
# ### Clinical features

# %%
cs['bmi']
# Out:
# 345    21.6
# 173    20.9
# 318    22.1
# 305    22.7
# 311    25.3
#        ...
# 234    25.8
# 87     24.4
# 236    38.3
# 54     18.0
# 247    34.2
# Name: bmi, Length: 385, dtype: float64

# %%
def get_sex(x):
    map = {
        'male':1,
        'female':0
    }
    return map[x]
def parse_yesno(x):
    map = {
        'Yes':True,
        'No':False
    }
    return map[x]

def get_smo_status(x):
    map = {
        'Former': 0,
        'Current':1,
        'Never':2
    }
    return map[x]

cs['age'] = cs['Age']
cs['sex'] = cs['Sex'].apply(lambda x: get_sex(x))
cs['bmi'] = cs['BMI:'].astype(float)
cs['phist_extrathoracic'] = cs['Does the patient have a history of extrathoracic cancer?'].apply(lambda x: parse_yesno(x))
cs['phist_primary'] = cs['Does the patient have a history of prior primary lung cancer?'].apply(lambda x: parse_yesno(x))
cs['phist'] = (cs['phist_extrathoracic'] | cs['phist_primary']).astype(int)
cs['fhist'] = cs['Family history of lung cancer?'].apply(lambda x: parse_yesno(x)).astype(int)
cs['emphysema'] = cs['Radiographic emphysema present?'].apply(lambda x: parse_yesno(x)).astype(int)
cs['copd'] = cs['History of COPD?'].apply(lambda x: parse_yesno(x)).astype(int)
cs['smo_status'] = cs['Smoking Status'].apply(lambda x: get_smo_status(x))
cs['pkyr'] = cs['Pack year history of smoking:']
cs['quit_time'] = cs['Years since quitting smoking: Enter 0 if still active smoker at time of bronchoscopy']
# Out:
# /tmp/ipykernel_3401216/2045154213.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cs['age'] = cs['Age']
# /tmp/ipykernel_3401216/2045154213.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cs['sex'] = cs['Sex'].apply(lambda x: get_sex(x))
# /tmp/ipykernel_3401216/2045154213.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cs['bmi'] = cs['BMI:'].astype(float)
# /tmp/ipykernel_3401216/2045154213.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cs['phist_extrathoracic'] = cs['Does the patient have a history of extrathoracic cancer?'].apply(lambda x: parse_yesno(x))
# /tmp/ipykernel_3401216/2045154213.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cs['phist_primary'] = cs['Does the patient have a history of prior primary lung cancer?'].apply(lambda x: parse_yesno(x))
# /tmp/ipykernel_3401216/2045154213.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cs['phist'] = (cs['phist_extrathoracic'] | cs['phist_primary']).astype(int)
# /tmp/ipykernel_3401216/2045154213.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cs['fhist'] = cs['Family history of lung cancer?'].apply(lambda x: parse_yesno(x)).astype(int)
# /tmp/ipykernel_3401216/2045154213.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cs['emphysema'] = cs['Radiographic emphysema present?'].apply(lambda x: parse_yesno(x)).astype(int)
# /tmp/ipykernel_3401216/2045154213.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cs['copd'] = cs['History of COPD?'].apply(lambda x: parse_yesno(x)).astype(int)
# /tmp/ipykernel_3401216/2045154213.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cs['smo_status'] = cs['Smoking Status'].apply(lambda x: get_smo_status(x))
# /tmp/ipykernel_3401216/2045154213.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cs['pkyr'] = cs['Pack year history of smoking:']
# /tmp/ipykernel_3401216/2045154213.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cs['quit_time'] = cs['Years since quitting smoking: Enter 0 if still active smoker at time of bronchoscopy']

# %%
clinical_ft = ['pid', 'age', 'sex', 'bmi', 'emphysema', 'copd', 'phist', 'fhist', 'smo_status', 'quit_time', 'pkyr', 'lung_cancer']
nodule_ft = ['spiculation', 'upper_lobe', 'nodule_size', 'nodule_type', 'nodule_count']
cs['pid'] = cs['MCL ID']
cs = cs[clinical_ft+nodule_ft]
cs
# Out:
# /tmp/ipykernel_3174113/3345588882.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cs['pid'] = cs['MCL ID']
#              pid  age  sex   bmi  emphysema  copd  phist  fhist  smo_status  \
# 345  27054566930   62    0  21.6          1     1      0      0           1
# 173  20802811825   61    1  20.9          1     1      1      0           0
# 318  24540308812   57    0  22.1          1     1      0      0           0
# 305  29479908093   71    0  22.7          1     1      0      1           0
# 311  14583998995   74    0  25.3          0     0      1      0           2
# ..           ...  ...  ...   ...        ...   ...    ...    ...         ...
# 234  34087001117   79    1  25.8          0     0      0      1           0
# 87    5434231673   59    1  24.4          0     1      0      0           0
# 236    450204236   56    1  38.3          0     0      0      0           0
# 54   41666093991   75    0  18.0          0     0      0      0           0
# 247   1585785419   69    0  34.2          1     1      0      0           0
#
#      quit_time  pkyr  lung_cancer  spiculation  upper_lobe  nodule_size  \
# 345        0.0  40.0            0            0           1          0.8
# 173        3.0  66.0            1            0           1          2.5
# 318        0.0  60.0            0            0           0          2.4
# 305       10.0  40.0            1            1           0          3.2
# 311        NaN   0.0            0            0           1          3.4
# ..         ...   ...          ...          ...         ...          ...
# 234       40.0  20.0            0            0           0          2.1
# 87         0.0  15.0            1            1           1          1.5
# 236       38.0   NaN            0            0           0          3.6
# 54        35.0   NaN            0            0           0          1.9
# 247        0.0  92.0            1            0           1          1.1
#
#      nodule_type  nodule_count
# 345            2             1
# 173            2             3
# 318            2             1
# 305            2             1
# 311            2             1
# ..           ...           ...
# 234            2             1
# 87             2             1
# 236            2             1
# 54             2             1
# 247            2             1
#
# [385 rows x 17 columns]

# %% [markdown]
# ### Get nifti scans

# %%
# scan_dir = "/nfs/masi/MCL/xnat/xnat20221207_bronch/bronch"
# rows = []
# for mcl in os.listdir(scan_dir):
#     for scanid in os.listdir(os.path.join(scan_dir, mcl)):
#         try:
#             scan_date = datetime.strptime(scanid, "%Y%m%d")
#             for fname in os.listdir(os.path.join(scan_dir, mcl, scanid)):
#                 rows.append({'pid': mcl, 'scan_date': scan_date, 'filename':fname})
#         except:
#             continue

prep_dir = "/home/local/VANDERBILT/litz/data/bronch/DeepLungScreening/prep/"
rows = []
for p in glob.glob(os.path.join(prep_dir, "*_clean.nii.gz")):
    scanid = os.path.basename(p).split('_clean.nii.gz')[0]
    mcl, date = scanid.split('time')
    scan_date = datetime.strptime(date, "%Y%m%d")
    rows.append({'pid': mcl, 'scan_date': scan_date, 'filename': scanid})


scan_df = pd.DataFrame(rows)
scan_df = scan_df.sort_values(by=['pid', 'scan_date'])
scan_df['session'] = scan_df.groupby(['pid'])['scan_date'].rank('dense', ascending=True) # assign a T0, T1, or T2 for each scan
scan_df['session'] = scan_df['session'] - 1
scan_df['session'] = scan_df['session'].astype(int)
scan_df
# Out:
#              pid  scan_date                 filename  session
# 162  10140118338 2018-10-19  10140118338time20181019        0
# 190  10232218755 2019-02-04  10232218755time20190204        0
# 334  10302863632 2019-02-16  10302863632time20190216        0
# 155  10310069205 2018-10-05  10310069205time20181005        0
# 250  10501496583 2019-01-08  10501496583time20190108        0
# ..           ...        ...                      ...      ...
# 218   8666755991 2017-12-01   8666755991time20171201        0
# 186   9057763661 2018-08-10   9057763661time20180810        0
# 136   9345567287 2018-07-13   9345567287time20180713        0
# 345   9473800086 2018-08-13   9473800086time20180813        0
# 73    9540380572 2017-11-06   9540380572time20171106        0
#
# [380 rows x 4 columns]

# %%
cohort = cs.merge(scan_df, on='pid')
cohort['id'] = cohort['filename'].apply(lambda x: x.split('.nii.gz')[0])
cohort['with_marker'] = 1
cohort['with_image'] = 1
cohort_path = "/home/local/VANDERBILT/litz/github/MASILab/DeepLungScreening/cohorts/bronch/bronch_prep_v1.csv"
cohort.to_csv(cohort_path, index=False)

# %% [markdown]
# ## Cross sectional cohort

# %%
xsectional = cohort.loc[cohort.groupby('pid')['scan_date'].idxmax()]
xsectional_path = "/home/local/VANDERBILT/litz/github/MASILab/DeepLungScreening/cohorts/bronch/bronch_cs_prep_v1.csv"
xsectional.to_csv(xsectional_path, index=False)

# %%
xsectional
# Out:
#              pid  age  sex   bmi  emphysema  copd  phist  fhist  smo_status  \
# 40   10140118338   62    1  25.8          0     0      0      0           2
# 359  10232218755   64    0  23.0          0     0      1      0           1
# 94   10302863632   65    0  18.9          0     1      1      1           2
# 324  10310069205   62    0  18.2          0     1      0      0           1
# 8    10501496583   41    1  30.0          0     0      1      1           0
# ..           ...  ...  ...   ...        ...   ...    ...    ...         ...
# 232   8666755991   69    1  28.1          0     1      1      0           0
# 207   9057763661   67    1  19.8          0     0      1      0           0
# 7     9345567287   37    0  20.2          0     0      0      0           2
# 311   9473800086   66    0  25.5          1     0      0      1           0
# 356   9540380572   70    0  26.6          0     0      0      0           0
#
#      quit_time  ...  upper_lobe  nodule_size  nodule_type  nodule_count  \
# 40         NaN  ...           1          1.2            0             1
# 359        0.0  ...           1          1.9            2             1
# 94         NaN  ...           0          1.2            2             1
# 324        0.0  ...           1          2.6            2             1
# 8          8.0  ...           0          1.8            2             1
# ..         ...  ...         ...          ...          ...           ...
# 232       17.0  ...           1          1.4            2             1
# 207       16.0  ...           1          1.4            2             1
# 7          NaN  ...           1          3.2            2             1
# 311       15.0  ...           1          2.1            2             1
# 356        3.0  ...           1          2.1            2             1
#
#      scan_date                 filename  session                       id  \
# 40  2018-10-19  10140118338time20181019        0  10140118338time20181019
# 359 2019-02-04  10232218755time20190204        0  10232218755time20190204
# 94  2019-02-16  10302863632time20190216        0  10302863632time20190216
# 324 2018-10-05  10310069205time20181005        0  10310069205time20181005
# 8   2019-01-08  10501496583time20190108        0  10501496583time20190108
# ..         ...                      ...      ...                      ...
# 232 2017-12-01   8666755991time20171201        0   8666755991time20171201
# 207 2018-08-10   9057763661time20180810        0   9057763661time20180810
# 7   2018-07-13   9345567287time20180713        0   9345567287time20180713
# 311 2018-08-13   9473800086time20180813        0   9473800086time20180813
# 356 2017-11-06   9540380572time20171106        0   9540380572time20171106
#
#     with_marker  with_image
# 40            1           1
# 359           1           1
# 94            1           1
# 324           1           1
# 8             1           1
# ..          ...         ...
# 232           1           1
# 207           1           1
# 7             1           1
# 311           1           1
# 356           1           1
#
# [367 rows x 23 columns]

# %%
# group nodules
bronch['lung_cancer'] = bronch['Final nodule diagnosis'].apply(lambda x: int(x=='Malignant'))
idxmax = bronch.groupby(['MRN'])['lung_cancer'].idxmax()
cohort = bronch.loc[idxmax]
cohort
# Out:
#      Record ID       MRN Final nodule diagnosis  Age     Sex  \
# 343        407  10053866                 Benign   62  female
# 170        209  10133197              Malignant   61    male
# 315        376  10227932                 Benign   57  female
# 302        363  10244135              Malignant   71  female
# 308        369  10567634                 Benign   74  female
# ..         ...       ...                    ...  ...     ...
# 232        285   9317355                 Benign   79    male
# 84         107   9608969              Malignant   59    male
# 234        287   9683517                 Benign   56    male
# 52          69   9822032                 Benign   75  female
# 245        300   9876590              Malignant   69  female
#
#      Size of Nodule (Specific) (cm) Smoking Status  \
# 343                             0.8        Current
# 170                             2.5         Former
# 315                             2.4         Former
# 302                             3.2         Former
# 308                             3.4          Never
# ..                              ...            ...
# 232                             2.1         Former
# 84                              1.5         Former
# 234                             3.6         Former
# 52                              1.9         Former
# 245                             1.1         Former
#
#     Does the patient have a history of extrathoracic cancer?  \
# 343                                                 No
# 170                                                 No
# 315                                                 No
# 302                                                 No
# 308                                                Yes
# ..                                                 ...
# 232                                                 No
# 84                                                  No
# 234                                                 No
# 52                                                  No
# 245                                                 No
#
#     History of cancer within the past five years? Location of nodule/mass  \
# 343                                            No                     RUL
# 170                                            No                     LUL
# 315                                            No                     LLL
# 302                                            No                     LLL
# 308                                           Yes                     RUL
# ..                                            ...                     ...
# 232                                            No                     LLL
# 84                                             No                     LUL
# 234                                            No                     LLL
# 52                                             No                     RML
# 245                                            No                     LUL
#
#      ... Pack year history of smoking: History of COPD?  \
# 343  ...                          40.0              Yes
# 170  ...                          66.0              Yes
# 315  ...                          60.0              Yes
# 302  ...                          40.0              Yes
# 308  ...                           0.0               No
# ..   ...                           ...              ...
# 232  ...                          20.0               No
# 84   ...                          15.0              Yes
# 234  ...                           NaN               No
# 52   ...                           NaN               No
# 245  ...                          92.0              Yes
#
#     Peripheral 1/3 of lung  \
# 343                    Yes
# 170                    Yes
# 315                    Yes
# 302                    Yes
# 308                    Yes
# ..                     ...
# 232                    Yes
# 84                     Yes
# 234                    Yes
# 52                     Yes
# 245                     No
#
#     Growth of primary nodule noted on surveillance imaging? Choose No if no prior imaging  \
# 343                                                 No
# 170                                                Yes
# 315                                                 No
# 302                                                 No
# 308                                                Yes
# ..                                                 ...
# 232                                                Yes
# 84                                                 Yes
# 234                                                Yes
# 52                                                 Yes
# 245                                                 No
#
#     Presence of pre-procedure symptoms? Includes: unexplained weight loss >5kg, dyspnea, pneumothorax, fatigue, pain or hemoptypsis  \
# 343                                                 No
# 170                                                 No
# 315                                                 No
# 302                                                Yes
# 308                                                 No
# ..                                                 ...
# 232                                                 No
# 84                                                  No
# 234                                                 No
# 52                                                  No
# 245                                                 No
#
#     Pre-bronch percent predicted FEV1 (%): Enter as an integer 1-110  \
# 343                                                NaN
# 170                                               20.0
# 315                                                NaN
# 302                                               56.0
# 308                                                NaN
# ..                                                 ...
# 232                                                NaN
# 84                                                68.0
# 234                                               75.0
# 52                                                 NaN
# 245                                               59.0
#
#     Years since quitting smoking: Enter 0 if still active smoker at time of bronchoscopy  \
# 343                                                0.0
# 170                                                3.0
# 315                                                0.0
# 302                                               10.0
# 308                                                NaN
# ..                                                 ...
# 232                                               40.0
# 84                                                 0.0
# 234                                               38.0
# 52                                                35.0
# 245                                                0.0
#
#     How was the nodule detected? Ensure you check the original reference scan in PACS  \
# 343                                    screen-detected
# 170                detected during active surveillance
# 315                              incidentally detected
# 302                              incidentally detected
# 308                              incidentally detected
# ..                                                 ...
# 232                              incidentally detected
# 84                               incidentally detected
# 234                              incidentally detected
# 52                               incidentally detected
# 245                                    screen-detected
#
#              Primary purpose of reference bronchoscopy lung_cancer
# 343                                         diagnostic           0
# 170  tissue sampling for molecular analysis (alread...           1
# 315                                         diagnostic           0
# 302                                         diagnostic           1
# 308                                         diagnostic           0
# ..                                                 ...         ...
# 232                                         diagnostic           0
# 84                                          diagnostic           1
# 234                                         diagnostic           0
# 52                                          diagnostic           0
# 245                                         diagnostic           1
#
# [387 rows x 39 columns]

# %%
cohort['lung_cancer'].value_counts()
# Out:
# 1    236
# 0    151
# Name: lung_cancer, dtype: int64

# %%
bronch_path = "/home/local/VANDERBILT/litz/data/bronch/Bronch MCL.csv"
bronch = pd.read_csv(bronch_path, dtype={'MCL ID': str})
bronch = bronch.rename(columns={'MCL ID': 'mcl_id'})

# %%
bronch
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 bronch
#
# NameError: name 'bronch' is not defined
